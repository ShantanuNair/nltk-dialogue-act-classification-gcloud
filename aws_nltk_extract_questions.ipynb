# %%
# NLTK Question Extraction Test
import nltk
import json
import random
from pprint import pprint
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import HashingVectorizer, CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from google.colab import files

print("Upload AWS Transcription job output (.csv) file.")
uploaded = files.upload()
transcription = next(iter(uploaded.values()))
d = json.loads(transcription.decode())
d = d["results"]["transcripts"][0]["transcript"]

nltk.download('nps_chat')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

posts = nltk.corpus.nps_chat.xml_posts()

def transform(post):
    tokens = nltk.word_tokenize(post.text)
    tagged_tokens = nltk.pos_tag(tokens)

    serialized = ['{}_{}'.format(z[0], z[1])
                  for z in tagged_tokens]

    text = ' '.join(serialized)
    text = text.replace('?', ' QQ')

    return text, 'Question' in post.get('class')

def extract_features(post):
    tokens = nltk.word_tokenize(post)
    tagged_tokens = nltk.pos_tag(tokens)

    serialized = ['{}_{}'.format(z[0], z[1])
                  for z in tagged_tokens]

    text = ' '.join(serialized)
    text = text.replace('?', ' QQ')

    return text

def train_classifier():
    pipeline = Pipeline([
        ('vect', HashingVectorizer()),
        ('tfidf', TfidfTransformer()),
        ('clf', SGDClassifier()),
    ])

    featuresets = [transform(post) for post in posts]
    random.shuffle(featuresets)
    size = int(len(featuresets) * .1)
    train_set, test_set = featuresets[size:], featuresets[:size]

    X, y = zip(*train_set)
    pipeline.fit(X, y)

    X, y = zip(*test_set)
    pred = pipeline.predict(X)

    # pprint([z for z in zip(X, pred, y)
    #         if z[1] != z[2]])

    print('accuracy %f' % pipeline.score(X, y))
    print(classification_report(y, pred))

    return pipeline




classifier = train_classifier()
# data = nltk.sent_tokenize("Is this how it's done? hi this is Jim how are you? is everything ok? what do you mean? why. what time do we start. im not sure ok? that's what I said, we use AWS and serverless")
data = nltk.sent_tokenize(d)
print("Classifier predictions on data:")


transformed_data = map(extract_features, data)
preds = classifier.predict(transformed_data)
print("Input:", data)
# print([("Q detected: "+ data[i]) for i, x in enumerate(preds) if x])
for i, x in enumerate(preds):
  if x:
    print("QQ:", data[i])
  else:
    print(data[i])
# Out:
# Upload AWS Transcription job output (.csv) file.
#      <input type="file" id="files-2ca3e8f1-1cf9-45da-8d6a-8d56e7f4ff3e" name="files[]" multiple disabled />
#      <output id="result-2ca3e8f1-1cf9-45da-8d6a-8d56e7f4ff3e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving transcript2.json to transcript2.json
# [nltk_data] Downloading package nps_chat to /root/nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# accuracy 0.972538
#               precision    recall  f1-score   support
#
#        False       0.98      0.99      0.98       939
#         True       0.90      0.85      0.87       117
#
#     accuracy                           0.97      1056
#    macro avg       0.94      0.92      0.93      1056
# weighted avg       0.97      0.97      0.97      1056
#
# Classifier predictions on data:
# Input: ['Well, thank you so much for comment.', "Let's start.", 'Tell us where you grew up.', "Tell us about Munich's this amazing city, right?", 'Or is it not?', 'Win the reverse sense, right?', 'I mean it.', "I think it's a lot better now than it used to be.", 'But I think Germany in general has been for a really long time, a relatively grim place.', "Um, you can raise money there, but, um, when I try to do that first in 99 you had to do a lot of things that I think me and my friends didn't have.", 'We were sneakers, and he did it suits and ties.', 'And you needed a great McKinsey background.', 'And we dropped out of college, which is, like, unheard of in Germany.', 'What did you What did you What did you want to be like?', 'What did your parents do for work?', 'Did you have these dreams of being an entrepreneur, or did you have dreams of doing something else?', 'What did you want to do?', 'I wanted to be a director on my life.', 'A director?', 'Yeah, a movie director.', 'Oh, movie director.', 'Okay.', 'I think like a director in a company.', 'I want to be middle manager.', 'I wanted to be in middle management at Wells Fargo.', "Was a death cash me to Yes, we're so like it was a great dream.", 'No, I wanted to be a movie director for as long as I can remember school.', 'I think that was literally the first thing that I told my parents that left to do.', "I don't know why that IHS e I know two things I love to.", "I had had a movie camera and I love to do slow motion videos with Legos Way before the Lego movie we're talking about when I was, like, 12 13 and I think I always, um I love telling people what to do.", 'So baby director does that to a certain degree as well.', "So maybe that's why that and so, um so So tell us just quickly about your career path.", 'You kind of bounced around in different companies.', 'You started it.', 'Will you start a company dropped at college?', 'He started this company.', "Let's start there.", 'What?', 'What was the company?', 'Give us the 12th pitch and tell us you raise a little bit of money from friends of family and tell us what happened.', 'The company is called seven a day.', 'Um and just imagine a marketplace that has a curious curated list seven products a day that the name kind of gives it away available, but the amount of them in stock is very limited.', 'And rather than telling you how much how many over the items are in stock, there is a bar that indicates that other people are buying these products and the price drops constantly throughout the day.', "So at some point you see the savings and you see that there is not many items left in stock, and we were betting on the fact that you're super ansi to purchase that product except nobody really did that there was in 99.", 'So to our defense, not many people bought anything but books online.', 'And we had lots of electron ICS and other stuff.', 'Even less people purchase something in Europe or in Germany.', 'So we had the company for around a year and we bootstrapped it.', 'Yeah, and and then what happened?', 'You just you shut it down or you did you guys just move on to other things or what what happened with your your team members and what we spend all our parents money at that time.', 'So we have we have to shut it down.', 'And when we decided to get jobs and maybe earn a little bit ourselves, did how did they feel about that?', 'Was that Ah, were they expecting?', "I mean, you're never you're never hoping to lose your money when you're vesting, but was was the expectation going in like, Hey, you're probably gonna lose your money.", 'Or was it like, did you sell them the dream?', 'And then it came kind of crashing down.', 'I think my parents have a relatively thick skin when it comes to losing money.', 'Um, things that have to do with me.', "The first, the first bill that we had the Internet, an Internet bill or a telephone bill, I think was at that time around 5000 Deutschmarks because I learned my parents into believing that it  ...
# Well, thank you so much for comment.
# Let's start.
# Tell us where you grew up.
# Tell us about Munich's this amazing city, right?
# QQ: Or is it not?
# QQ: Win the reverse sense, right?
# I mean it.
# I think it's a lot better now than it used to be.
# But I think Germany in general has been for a really long time, a relatively grim place.
# Um, you can raise money there, but, um, when I try to do that first in 99 you had to do a lot of things that I think me and my friends didn't have.
# We were sneakers, and he did it suits and ties.
# And you needed a great McKinsey background.
# And we dropped out of college, which is, like, unheard of in Germany.
# QQ: What did you What did you What did you want to be like?
# QQ: What did your parents do for work?
# QQ: Did you have these dreams of being an entrepreneur, or did you have dreams of doing something else?
# QQ: What did you want to do?
# I wanted to be a director on my life.
# QQ: A director?
# Yeah, a movie director.
# Oh, movie director.
# Okay.
# I think like a director in a company.
# I want to be middle manager.
# I wanted to be in middle management at Wells Fargo.
# Was a death cash me to Yes, we're so like it was a great dream.
# No, I wanted to be a movie director for as long as I can remember school.
# I think that was literally the first thing that I told my parents that left to do.
# I don't know why that IHS e I know two things I love to.
# I had had a movie camera and I love to do slow motion videos with Legos Way before the Lego movie we're talking about when I was, like, 12 13 and I think I always, um I love telling people what to do.
# So baby director does that to a certain degree as well.
# So maybe that's why that and so, um so So tell us just quickly about your career path.
# You kind of bounced around in different companies.
# You started it.
# QQ: Will you start a company dropped at college?
# He started this company.
# Let's start there.
# QQ: What?
# QQ: What was the company?
# Give us the 12th pitch and tell us you raise a little bit of money from friends of family and tell us what happened.
# The company is called seven a day.
# Um and just imagine a marketplace that has a curious curated list seven products a day that the name kind of gives it away available, but the amount of them in stock is very limited.
# QQ: And rather than telling you how much how many over the items are in stock, there is a bar that indicates that other people are buying these products and the price drops constantly throughout the day.
# So at some point you see the savings and you see that there is not many items left in stock, and we were betting on the fact that you're super ansi to purchase that product except nobody really did that there was in 99.
# So to our defense, not many people bought anything but books online.
# And we had lots of electron ICS and other stuff.
# Even less people purchase something in Europe or in Germany.
# So we had the company for around a year and we bootstrapped it.
# QQ: Yeah, and and then what happened?
# QQ: You just you shut it down or you did you guys just move on to other things or what what happened with your your team members and what we spend all our parents money at that time.
# So we have we have to shut it down.
# QQ: And when we decided to get jobs and maybe earn a little bit ourselves, did how did they feel about that?
# QQ: Was that Ah, were they expecting?
# I mean, you're never you're never hoping to lose your money when you're vesting, but was was the expectation going in like, Hey, you're probably gonna lose your money.
# QQ: Or was it like, did you sell them the dream?
# And then it came kind of crashing down.
# I think my parents have a relatively thick skin when it comes to losing money.
# Um, things that have to do with me.
# The first, the first bill that we had the Internet, an Internet bill or a telephone bill, I think was at that time around 5000 Deutschmarks because I learned my parents into believing that it wouldn't be that expensive.
# And I spent nights and days and, you know, you have to buy these excess codes and pre a well, So that was the first thing, then I think they lost a ton of money because of me in the stock market.
# Because at that time I convinced him to buy Apple stock, which then went nowhere for for sometimes that was another 10,000.
# So they were used to the fact of losing money was my craft.
# QQ: Have you paid him back yet or?
# Yeah, I know I did.
# Okay.
# Good out there.
# Was very proud.
# Yeah.
# QQ: How long did that take?
# Just, I think, a monster horse.
# QQ: So you paid him back a month ago?
# Yeah.
# So it's already eight now, so to wait.
# 20 years, but later than ever.
# Yeah, well, that's way better than ever.
# It's like like a student loan.
# Except, you know, I dropped out.
# So that's awesome.
# That's really cool.
# Um, they must be very proud.
# Now, I'm sure.
# Eso tell.
# Tell me.
# Tell me how you met your co founders.
# QQ: How did how did you meet Sean?
# QQ: How did you meet Sam?
# This is fast forwarding.
# Almost 10 years from there.
# QQ: But how did how did you meet these two guys?
# Well, I Sam was a friend of mine in London.
# Um, I moved from I moved from living in Germany, in Munich, in Berlin.
# I moved to the UK to London.
# I worked for P A consulting.
# It's a consulting firm.
# They say I don't even remember in details anymore what I did there because it's it's really boring, mind numbing stuff.
# They're doing lots of government work and, um but they pay.
# You were all so you know, you get it, um, you get a huge salary and you gotta you get a great bonus so that can calm you down for force.
# And you were a director.
# So is no, I I think I They had in innovations arm called Aipac's.
# And I worked in that team there on product development.
# And that's when I met Sam.
# And we met Sean over here in the U in the US come because both of the companies that we're working on at that time were part of the first angel pad batch.
# Our company was called curated by in the company of Sean.
# Our third co founder was called Huck Energy.
# QQ: Okay, And And how did what happened with Curated by How did how did that kind of evolve into Postmates secure?
# Aided by was, I think was just a really the other thing that I knew um, for almost as long as I can remember is that at some point I would love to have a company in the United States in the Valley.
# So even when I was 14 15 years old, um, you know, I had that being a director dream, and I think relatively shortly after that, the other thing that would interest me was to run a startup in, in In in Silicon Valley.
# And I read so much about it.
# And of course, you read the newspapers and you read the things and you're inspired by the companies.
# In my case, it took a bit longer to get here, but it had always been my dream.
# So, um, was the company curated by we just met Two Most Corte who was one of the guys who runs Angel Pattern.
# He's German.
# And even though the idea was incredibly stupid, he said, You know, I'm sure you guys figure out eventually what you want to do.
# But if you guys come to the States, I'm going to introduce you to the network that I have.
# And that was an opportunity that that I just couldn't resist, given the fact that for the last 15 plus years.
# I you know, one of your dreams.
# Yeah.
# QQ: And so what happened?
# You got here, You You go into the way.
# We pretty much figured out that the idea is completely stupid.
# And, um, that it's not something that we want to spend the rest of our the rest of our lives on.
# Um, we also had a really hard time raising money.
# You talked about Navalny earlier.
# I give you a quick story about novel how I met him.
# We pitched him as an angel investor is actually a great story That probably shows a little bit of resilience and how important it is to, like, keep in touch with people So way pitched him.
# And he said, You know, here seem like a cool guy, but that's never gonna work.
# And, uh, custom curated by pitching curated, Yeah, and and really to just think about curated by think about it.
# It's a curation tool that allows you to put content predominantly tweeds into bundles that you're an expert, often share that with other people.
# So there's all that stuff out there, and we thought it would be great if to give you better tools to curate that information.
# And so we pitched him on that, um and and and he didn't want any of that.
# But he said, you know, I'm doing kind of a startup myself.
# Angel list.
# He just started doing that and he said, Why don't you guys join me as venture hackers and you're going to get a 1,000,000 in equity each.
# And you and Sam, you know, we could really do something cool together.
# We thought about this for the day, and then we declined.
# And we said, You know, this is awesome.
# QQ: Like for you to join the Angelis team?
# Yeah, he basically turned a VC pitch into a recruiting pitch on his son.
# And he's good at that.
# Yeah.
# Um, and I don't know.
# Many of you know, one of all you all should know him.
# I think he's a little bit more difficult to get hold of these days, then 2000, 10,000 women.
# But he's a great guy if you have a chance to talk to him.
# So he tries to turn this conversation to recruiting pitch.
# We decline.
# But I asked him one question in that recruiting pitch, and that is what happened I asked him what would happen to the money that we has raised.
# So the money from Thomas and that that impressed him because, um, if you guys read about what nerve all did in the past, he he had his rough.
# Petrus two was investors in the Valley and, um, thrown out of his company thrown out of this company.
# So he was impressed that we would that we would be concerned about not burning any bridges with the investors into Postmates.
# And he said into curated by and he said, You know, we would take care of them but we still declined the offer.
# But fast forward 66 months later was only six months when we started working on Postmates.
# He was the first person that we pitched and he had just invested in uber, I think three or four months earlier, and we walked in the office and it was the three of us.
# So he knew us from Angel Pat and we had, um just a working prototype and literally always showed him is like that we could enter something on this iPhone and the other iPhone, the Postmates Courier iPhone would beat, and you would see these two people moving on the map.
# And he he wrote a check over $250,000 in that meeting.
# Um, and he let our seat.
# Wow.
# I just thought that's a great story.
# That is a great story.
# Yeah, that's never happened in any of my meetings with him.
# Yeah, um, I'm kind of upset about it now.
# QQ: Um What?
# QQ: What?
# QQ: Where did this idea come from?
# QQ: Where did where did Postmates where did your do curated by Okay doesn't work.
# QQ: Then where do suppose makes come from?
# QQ: What's the genesis of the idea?
# So I have this ledger of ideas just like I'm sure you guys all have that and some of them just keep haunting you.
# And Postmates was one of these ideas that just kept haunting me.
# I had the idea just when I moved to London, I moved from Munich to London.
# And believe it or not, I had this, you know, you whole coming by and we loaded it and drove all the stuff to my parents players because, you know, you don't really want to take it all in in a new city in another country with you at first, and they forgot to take my snowboard.
# So I'm I'm a week.
# Our there's basically nothing in my house.
# I'm staying at a friend's place and there's to snowboard still there, So I'm trying to figure out how I can get my snow.
# But to my parent's place, um, ups FedEx cost a fortune.
# In Germany, the item is considered frayed.
# They want you to wrap it.
# The whole thing was just horrible.
# So I started calling local Korea companies and they just gave us, gave me weird quotes.
# Some would tell me that they could do it in two months because they had a trip plant.
# My parents live outside Berlin.
# It's 500 miles or some.
# That's something they could do tonight.
# Charged 400 euros.
# So it was just a wild world out there.
# QQ: But what would happen is that two days later, a friend called me and he said, You know what?
# I'm driving up to blend.
# You just want me to drop this off your mom's place.
# Now Germany is very different geography wise than the United States.
# You have 80 84 million people.
# You have a load off cities with a 1,000,000 plus people in relatively close proximity.
# People travel a lot on the weekend.
# Students that study and frank for drive back to Munich or drive to Cologne.
# People from Hamburg visit Berlin, so you have a lot more traveling throughout the country than you have it in the US, and right sharing had already been a huge thing.
# People leverage right sharing very differently because of that infrastructure of people traveling.
# So the original idea of Postmates that the very, very 1st 1 was just what if you could, like, create a friendly aversion and, like the Postal Service, like where your friends carry the stuff for you because they already travel to a destination anyway?
# QQ: Was the seal time that the U experiences?
# I mean, that's kind of Ah, it's kind of a rare use case, right?
# Like where you forget something totally different than like I'm hungry every single day.
# And I'm too lazy to go, you know where I don't have the time to go.
# I mean, that happens all the time, right?
# QQ: I mean, did did you like, did you think wow, this this could be huge thing?
# Or was it like, Hey, I'm just going to solve this problem.
# And I mean, did you This market could be that early on Or was it was it?
# QQ: You know, Did you think you're gonna use it every single day?
# QQ: Or do you think I might use it once a month or what?
# QQ: What did you think?
# QQ: People?
# QQ: How did you think people would use it?
# Where I think he is An interesting thing, that that probably happens very often when you when you have an idea and that that is probably that you that you're so euphoric about the idea and that you are so excited about what you have discovered that at least for myself, I'm often when the when the idea is just it's just very fragile and it's still very young.
# You get you get so excited about everything surrounding it that I think you can over project the frequency of use off these things.
# And I remember that definitely back at the time, we were like, Oh my God, if it's that easy, people will clearly do it more off just because it's that easy.
# And I think that's actually one of one of the dangers off when you when you start with an idea of getting married to a specific thing too early.
# I mean, for Postmates, it's It took then four years, and it took a couple of it orations for us to figure out that that's actually not the use case that would ever grow that company fast.
# At some point, we figured out it's prepared food, and by 45 years I mean, like, obviously didn't work on the idea for a long time.
# But even when we got back to the idea, we started to look at it from an angle of, like, delivering things within your city.
# QQ: But we still hadn't figured out the idea like, What is the trigger?
# QQ: What's the most frequent inventory in a city that you can use every day?
# And it turned out that that will be prepared food.
# But customers did guide us way we.
# It was none of us just waking up one day and saying like it's a no brainer.
# We do prepared food, and sometimes that is probably because how you think about the product, you think about it and like its ultimate form.
# And I think that's totally what Postmates will be that then, if you need to do something like the stuff I had to do was most nobody's available.
# But in order to get there, you're probably I think that the way to get there is what we missed at the beginning.
# QQ: So when you launched, how did you launch originally?
# QQ: Did you have your own drivers and riders?
# QQ: Did you Did you use other existing infrastructure?
# QQ: What did you do at the very beginning?
# We signed up every any every existing messenger company in San Francisco.
# We signed up on the platform, their herds, their own 25 or 30 of them, and I would run around and we would pitch them one by one.
# And we would give them iPhones.
# And we would tell them like, Look, you know, you don't have much to do, So, uh, he here's a great way because we will have a lot off things to do for you.
# So be part of this.
# And did it work didn't work.
# QQ: Why not?
# QQ: What?
# They were all excited about it.
# But, you know, I think the messenger industry in general is like is like an industry that has been, um, they have been really like there have been like pushed almost unlike the like the outskirts off society.
# QQ: They like the renegades, right?
# I mean, they there was a time, and it meant it was a glorious thing.
# And when when everybody needed messengers and in cities like New York and San Francisco there were big and thriving.
# And and then, you know, pdf came along, a lot of other things happened.
# So being a messenger kind of pushed you more and more into, like, one off jobs, not very regular customer relationships, very comparable products.
# And so they that that whole community became a little bitter and it became a little guarded.
# And and I think that's what we felt when we started working with them.
# It becomes more of a lifestyle than it.
# Then it really becomes a business.
# And And you were talking about your customers kind of guiding you.
# Um, I read about a story where basically you your customers started writing in the notes in the app and saying, Hey, we want I don't want you to bring me this furniture.
# But I I would like you to bring me some food or would like you to bring me this or that.
# Tell us about that, how that evolution happened and then the shift that you made in the company.
# That is actually an upsetting story, because we, the first version of post ments that we created, was a beautiful product.
# It looked like a note pad, and it was designed for local merchants.
# We had talked to hundreds of merchants in San Francisco, and we had determined that the biggest pain point for them is that somebody comes in the store, wants to buy a product, and they can't deliver it.
# So we've designed an app that would do that for them.
# Um, it's an app that they could install.
# Or they would even give them in some cases and and iPod or whatever to run it on and two taps you enter the pickup pretty fall, that's your store, you enter a drop off, and we signed up every single furniture store in San Francisco three or four years ago, and there were also excited to use the app Um, and then we built the up for them and nothing happened.
# As in, there wasn't many stores that actually used it, and they used that.
# They used it every once in a while, so we started talking to them.
# A long story short.
# What happened in instead is that customers who would download the at the AP they would as a pickup, enter a store or a restaurant and in the description field they would just type a shopping list and they would send off that request to the network.
# And we had to cancel a lot of these orders simply because we didn't have any payment infrastructure in place.
# And this is why it's so such upsetting story because we built this product for the wrong audience.
# We build it for the merchant when where we should have started is the customers.
# Because it turns out that everybody loves the idea that you can point your cell phone like a remote control at a store and you can type down what you want.
# And you have these items delivered in a couple of minutes.
# Um, and we didn't see that at all.
# What we saw was the need from the merchant side.
# QQ: And so what changed?
# QQ: What shifted and and when you change the product, what happened?
# Oh, money.
# I mean, we did a test one weekend, and I think we sold $10,000 worth of merchandise on on the first.
# On the very first weekend, we send out an email and we said, You know what, guys?
# This weekend, if you're usedto hashtag, get it now and you enter the items that you want, we're going to get him to you and we At that time I think we had 25 or 30 Postmates.
# QQ: This is on Twitter something or what?
# It would mean The hashtag way needed a trigger to guide you to a post made who would have a payment method.
# And what we did as a payment method is we came from a prepaid gift cards, so we bought tens of thousands of dollars.
# Worse we, by the way, everybody should try that once in his or her life.
# Her of his life.
# Go to a safe way with a credit card and tried to buy $10,000 worth of Visa $100 gift cards.
# It's the greatest experience in your life.
# They called the cops twice, and it's totally insane.
# And then try to explain your bank.
# QQ: Who's blocking the transaction?
# Why you're buying $10,000 worth of visa gift cards it's it's totally cool, Um, and and it's even better if you have to do that when you when you run out of money and it's like eight or nine oclock and you have to go to one of the dodgy Safeways because you basically show it all the other one hearts on all the other one.
# That's a true story.
# We sold out almost the entire city of San Francisco someone.
# There were only $50 gift cards left, and we will distribute them to the fleet because at that time we didn't have another payment method.
# But once we started this experiment, we had to obviously keep it going and people wanted it and wanted more and more and more of it.
# So, um, we wrote some clever systems on for curious to keep a tally we show on, my co founder invented a system that would auto dial.
# They want 800 numbers on the back off a visa gift card to check the balance so that we could have some sort of like understanding on wherever stand.
# Um, yeah, there was crazy.
# QQ: Where did you find these original writers?
# QQ: Where did they come from?
# So at some point, I think we just did, um, to things.
# We did ads at universities at college boards and we did cracks.
# This That's OK. That was the very first does.
# It was your first dozens of Postmates.
# QQ: Yeah, and And how did you What did you learn from from those very first ones?
# QQ: And how did that change over time turns?
# QQ: Who you recruited, like, Who is your Who is the perfect post mate for you guys?
# We probably didn't pay enough attention to the rich.
# Probably should have.
# Should have paid way more attention to the to the couple of first ones.
# I think the learnings on the supply side have been for the people who follow the company.
# I think we did not pay enough attention to the supply side until about 18 months.
# Two years in.
# And there was a time when it was a lot of it has been written that, you know, it was impossible to get a post made to accept the delivery.
# And I think until we really hit it big attraction.
# QQ: We probably didn't care about the supply side understanding who they are from a monetary compensation.
# We or we always cared about them but understanding who they are and what drives them.
# We probably neglected that side of the business for I would say 18 months.
# QQ: And what about now?
# QQ: Like what?
# When you think of the Postmates.
# QQ: What?
# QQ: What is so great about your product that keeps them coming back?
# QQ: What?
# QQ: What do you How do you think about them?
# QQ: What?
# QQ: How do you How do you look?
# A look at them.
# So we have this metrics internally, and the cool thing about it is after after after somebody did 10 deliveries, we know if that's going to be a power post made or a regular post made.
# So one of the things that we're that we're trying to do is to understand the 1st 10 deliveries.
# They define the experience for Postmates on the Postmates platform, and we're trying to do a lot of design and understanding and measuring around those 1st 10 deliveries before that.
# Um, it is a bunch of boring stuff.
# Ah, that that it's probably not as exciting and a lot of it has to do with a relatively deep source list.
# That means not just relying on one platform, but we have I would say 2030 channels for the supply side acquisition rather than just relying on Praxis stance.
# So many interesting things about this thing company and about your story in particular.
# I think one of those is that you were talking about you guys starting this in 2011.
# And I can I moved here in 2005 and I can remember to those 11 very clearly and every startup that I met at start of grand, wherever else was working on, like a group on cologne or an incubator.
# You know, it was like there were these, you know, and you see it today.
# There are all these themes and it just kind of comes in and and now it's like we're in 2015.
# It's four years later and like on demand is just the rage, right?
# And and here you guys have been working on it for years and years and years, and it's like it's like you're this startup that is an overnight success.
# QQ: Five years, four years in the making, and I wonder, like, What has that been like for you?
# Is somebody that's been toiling away, You know, just on this concept and figuring it out.
# QQ: And as you see all these people coming in, what like how do you What is your perception and what are your thoughts on how hot this whole topic has become and all these people that have kind of jumped into the space?
# So we knew that this would be huge.
# I don't know why.
# And I don't mean Postmates.
# I'm in this space.
# Um, I don't know why, but when when we started the company in 2011 I think there were already a lot of signals that would point towards a world that works faster than then than the current work and then the current world.
# And we I don't think we had an idea on how much impact on demand space could have on commerce.
# QQ: But I think what we did that we looked at the status quo, and we looked at how the world works, works and how it used to work.
# And I think a good indicator on how the future is going to be is that it probably doesn't look anything like the past.
# So, you know, rather than believing that the space will be good, we also had really deep believe, believe in ourselves that this is something that we want to do.
# And I think sometimes that's more important than just riding a wave that you can already see, right?
# I mean, some of the best serve you get if you wait out there for like, you know, 34 hours, others leave.
# The others leave, go back to the beach, drive home.
# But if you wait long enough sometimes debt wave that wave, that perfect waves, a couple of them, the 10 12 minutes build up and you have an amazing surf.
# And and and I think that's kind of how we felt now, how we feel now in that space, I'm not saying that we feel that we're the best in that space.
# But there is something cool about the fact that if I look back what I talked about four years ago, it's the same crap to talk about today, right?
# So but but it it kind of happened, that's that, to me, is interesting.
# Um, up until a year and 1/2 ago, you all had not raised more than 10 more than single digit millions of dollars, and I wonder if you could talk to us a little bit about what your experience was with investors.
# You have some of the best angel investors in the valley.
# Um, but when you got to your first year, Siri's a round talk to us.
# QQ: Like, was it?
# QQ: Did people get it?
# QQ: This is just a couple of years ago, but did people understand where this was going?
# QQ: It that they figured it out?
# QQ: Um, you know what?
# QQ: What was that experience like?
# Yes.
# So I think I have a good read on that now because actually thought about this a lot.
# I thought about just for some background.
# We had a great time raising a seat round, and you're right.
# We had some really smart investors in the Cedrone, and then we had a really tough time raising our Syria's A and ultimately Founders Fund.
# Let the Syria's A and Bryan Singer minute founders funded and everything was great.
# But I think what happened is the following.
# Um, we knew that the space would work out to be something really exciting.
# And for angel investors, that's probably all that they care about.
# They care about a group of really smart people, really passionate about a topic And is that person then telling a convincing story why the company that they're start to build can be one of the forerunners?
# If that space is gonna happen now, that's probably all you need to raise your seat round and to raise.
# Maybe, you know, whatever you call it an angel round.
# But when we came to the first institutional investors, a lot of what we were talking about it hadn't happened yet.
# So in in end of 2012 when we raised our serious A, we didn't have any Starbucks.
# Walgreens, 7 11 Chipotle, a strategic partnership.
# We didn't have millions off deliveries.
# We didn't have tens of thousands of couriers or hundreds of thousands of dollars in sales on the platform.
# It was still us just talking about it.
# And that was a lot for them to believe that a the space would develop and B that we would be one of the companies that, in whatever sends that term makes any sense, would lead that space.
# So you have the same guys running around.
# The product looks great, but the the volume is very low.
# There's no partnerships now.
# We know it's just because the space and the world just probably needed another year or two until you know more and more companies enter that market to to really push the market.
# But I think that's what happened.
# So sometimes you can almost be a little bit too early and and and I believe that's what happened to us in the Syria say there were no competitive, uh, almost no competitors, very few data points to look at.
# So you know, you you got to believe in these guys hard if you if you race, if you lead the Syria's A because it's institutional money, it means a lot.
# It's just different things that that someone like an institution investor looks at then your angel or seed investor and what ultimately, push it over for you.
# You you you met with all the top investors in the Valley.
# Basically, most of them said no and they never say no.
# They say, You know, let's keep talking.
# Nobody says no, That's the old rule, right?
# Right.
# That's what's the most frustrating part is because nobody ever says no, they're just say like, That's cool, but keep me updated.
# Yeah, why don't we keep keep sending me those updates.
# Yeah, Yeah.
# They don't want to say no.
# QQ: And so what?
# Finally pushed it over the edge.
# The edge for you.
# QQ: What do you What do you think it was with the Founders Fund?
# QQ: Um, you know what?
# QQ: What changed with them?
# QQ: Was it something with them?
# QQ: Was it something in the way you pitch?
# QQ: It was the way the you you thought about it or pitch to differently or what?
# QQ: What had the big impact there?
# I think one other receiver and put out a term sheet that wasn't very favorable for us.
# And, um, we told Founders Fund that we have that term sheet, and then they put out one That was clearly better.
# Um, and that's how they deal came about.
# So I I can't tell you what it really was.
# At the end of the day.
# I I think it's It's Bryan Singer, man, convincing Peter Thiel and Luke and, um, everybody else Kenny at at Founders Fund that this is a great deal.
# Um, I love that 80% of your traffic is word of mouth.
# Um, you haven't spent any money on marketing.
# We do a little bit.
# You do now.
# OK, we do live.
# QQ: Um So first off, how do you measure that?
# QQ: How do you How do you measure is you know, how do you measure the 80%?
# QQ: And then what do you What do you attribute that to?
# QQ: What part of the experience is so great that people want to talk about in share with their friends?
# Go Well, they mean the you can't really measure.
# Word of mouth is up to the digit.
# But if you spent money and you know, let's just say we're installs, you get back and you get, you know, 80% more than you have a clear understanding on kind of what you're spending foreign and what is organic.
# A word of mouth is I think the reverse is actually easier than trying to figure out if this is all word of mouth and then you get into problems.
# What word over mine was a lot of it has probably been pressing people inviting other friends.
# So there's elements that you contract, and then there's a little bit of unknown this'll area.
# Sometimes stuff just happens.
# QQ: Um, and the other question was how we attributed to what?
# QQ: Yeah, like what part of the experience like what makes it so great?
# QQ: What?
# QQ: You know, what is what is the point where the user says This is something that I want to tell my friends about this what part of it is is so different and interesting for people.
# I mean, at the very beginning, it was just something that you couldn't get anywhere else.
# So I think we were lucky enough that at the time that we launched, even though it was maybe a little bit early you had and an early adopter circle of people that are just used it and they're like, what just happened?
# Because it is hard to understand that.
# But there was no substitute.
# Like the Onley substitute was for you to do it yourself any off that, um and I get it now.
# There's like, eight or nine companies and everybody gets a $1,000,000 that's cool.
# But there was nothing there.
# So I think that use case in itself that you can point your mobile phone at a store and you see a menu in the best.
# Gays are often you didn't and you type it in.
# And the average delivery time in San Francisco is 28 minutes later, you get something.
# That's that's pretty cool.
# Yeah.
# So, just being first, there was a huge first.
# There's a first mover advantage for you guys.
# Just being the first option.
# Get getting a physical product delivered in the couple of minutes.
# Yes.
# Yeah.
# QQ: What is the What is the future of this market look like?
# QQ: Where things going, Where do you What do you think about when you think about where things are gonna be in five or 10 years?
# QQ: I mean, it's impossible to completely predict, but, like, what do you think about What do you think's gonna happen to this market?
# I obviously think it's going to grow.
# I I don't think I know it myself.
# Um, which is probably alarming somewhat.
# Um, but what I mean by that is I on demand services Could could go one of two ways.
# They I think we could see a future where, um, there is one or two destination APs or websites where you go to and you get things like an Amazon is today in the world of commerce.
# Or it could be a more distributed version so that that could lend itself more towards a platform play, as in PayPal or an infrastructure for deliveries, period.
# QQ: But where?
# Which over the two or of the two could live with each other.
# I I'm not I'm not so sure about yet.
# Tell us.
# Just give us some of the stats about Postmates.
# QQ: What?
# Tell us about the growth.
# Tell us about where things are at today and and, Ah, tell us.
# Brag a little bit for us.
# QQ: Does anybody nobody really wants to?
# Well, I want to know a nine.
# And I have the mike, so no way.
# Um, by December, we will do a 1,000,000 deliveries a month.
# Wow.
# On on the platform.
# And, um, this year, the company will grow 88.5 acts.
# So it gives you an indicator where we were at the beginning of the year.
# No, we're over halfway there to the goal, which we better because it's almost October.
# Unless we want to grow 100 and 50% in December.
# Uhm, we're making headway.
# Um, I think another number that we that we used before is that we have I think it's just under 14,000 Postmates doing deliveries in 30 cities.
# Um, and um, we're launching a whole bunch of cities more soon.
# Um, so it's, you know, we're happy where it's at.
# There's one thing that I'm actually the most proud of, and that is that we have made money from Day one.
# So that sounds totally insane.
# We had almost from the entire start a positive gross profit margin, and we usually like our gross profit margin anywhere between 15 and 20% in any given month.
# Sometimes there's some seasonality in there.
# So, um, if you complain by Postmates is sometimes expensive, then the answer is because we like to make money.
# Um, but it jokes aside, it has been, I believe, it was important for us as a company to figure out a business model, especially in a space where it's just us telling people that this is going to be an interesting space.
# QQ: At some point, we'll and what was their I mean, what's been the reaction over the last few years in the Valley?
# I mean, we've I think, that the mindset of being a revenue first or revenue thoughtfully you know, driving revenue companies has changed where now it's like every y c cos he now is making some money or has a very clear business model that they're talking about.
# But, I mean, that was another big differentiator.
# QQ: You think about three or four years ago, Like who was talking about making money?
# You know, in these scalable startups, it just wasn't something that people were referring to.
# And here you are, thinking about it from day one and and, you know and now we're seeing I can't remember what the term is that they're now using for the failed unicorns that the unicorns that are dying.
# But you see these companies that have mismanaged marketing spent, you know, they've mismanaged their funds and they've just been growing because of the marketing.
# Um, and it just seems like a huge competitive advantage for you guys.
# I mean, all I can say is that I've I've pitched partners at BC firms that had no idea how even to get to gross profit when they look at the financials off a company so that there's probably choose in in in what you said.
# I think the more mature company it is, the more important it is to to have that figured out.
# I think if you can't show unit economics.
# If you're in the business off selling stuff or if you're in the business off actually making money, then our unit economics look a lot like Uber's.
# But with G. M. V so way like that.
# QQ: What?
# QQ: What is the future of Postmates?
# QQ: Look like?
# QQ: What is?
# You know, you're sitting here in five years from now.
# QQ: What is what is what is Postmates?
# QQ: Where do you see you going?
# Well, I think we always had this dream that it could be they become like that sounds incredibly boring, but that it could be like a utility, just just something that's there.
# Um, so if you purchase products, there's a button for that.
# You know something that's reliable, that that is part of a city that's part of a community, that it's part of interactions that is part of commerce Eso You know, it is not so much swinging for the fences, but more like becoming like an infrastructure that a lot of people can use.
# Let's give bashing a big round of applause.
# Thank you so much for being here
